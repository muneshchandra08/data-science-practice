# %%
import pandas as pd
import numpy as np

# %%
d1 = {'Name':["raj","ramesh","mary","sachin"],'Age':[23,34,36,32],'Height':[180,170,165,156]}

# %%
d1
# Out:
# {'Name': ['raj', 'ramesh', 'mary', 'sachin'],
#  'Age': [23, 34, 36, 32],
#  'Height': [180, 170, 165, 156]}

# %%
# Use of zip()
# Define two lists
list1 = ['a', 'b', 'c']
list2 = [1, 2, 3]

# Use zip() to combine the lists
zipped = zip(list1, list2)

# Convert to a list and print the result to see the pairs
print(list(zipped))
# Out:
# [('a', 1), ('b', 2), ('c', 3)]

# %%
L1 = ["Raj", "Ramesh", "Mary","Sachin"]
L2 = [23,34,36,42]
L3 = [180,170,165,156]
L4 = ['M','F','F','M']

# %%
df2 = pd.DataFrame(zip(L1,L2,L3,L4), columns =["Name","Age","Height","Gender"])

# %%
df2
# Out:
#      Name  Age  Height Gender
# 0     Raj   23     180      M
# 1  Ramesh   34     170      F
# 2    Mary   36     165      F
# 3  Sachin   42     156      M

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Age     4 non-null      int64
#  2   Height  4 non-null      int64
#  3   Gender  4 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 260.0+ bytes

# %%
df2.columns
# Out:
# Index(['Name', 'Age', 'Height', 'Gender'], dtype='object')

# %%
array = np.array([["Raj",23,167],["sachin",45,166],["ramya",27,165]])
array
# Out:
# array([['Raj', '23', '167'],
#        ['sachin', '45', '166'],
#        ['ramya', '27', '165']], dtype='<U11')

# %%
len(df2)
# Out:
# 4

# %%
df3 = pd.DataFrame(array, columns = ["Name", "Age", "Height"])
df3
# Out:
#      Name Age Height
# 0     Raj  23    167
# 1  sachin  45    166
# 2   ramya  27    165

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      object
#  2   Height  3 non-null      object
# dtypes: object(3)
# memory usage: 204.0+ bytes

# %%
len(df3)
# Out:
# 3

# %%
df3.columns
# Out:
# Index(['Name', 'Age', 'Height'], dtype='object')

# %%
df3["Age"]= df3["Age"].astype(int)

# %%
df3["Height"]= df3["Height"].astype(float)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int32
#  2   Height  3 non-null      float64
# dtypes: float64(1), int32(1), object(1)
# memory usage: 192.0+ bytes

# %%
S1=pd.Series([10,39,67,90,100,21], index=['a','b','c','d','e','f'])
S1
# Out:
# a     10
# b     39
# c     67
# d     90
# e    100
# f     21
# dtype: int64

# %%
S1['a':'d']
# Out:
# a    10
# b    39
# c    67
# d    90
# dtype: int64

# %%
S1['a']
# Out:
# 10

# %%
df4 = pd.DataFrame(S1)
df4
# Out:
#      0
# a   10
# b   39
# c   67
# d   90
# e  100
# f   21

# %%
S1['e']=50
S1['f']=26

# %%
df4
# Out:
#     0
# a  10
# b  39
# c  67
# d  90
# e  50
# f  26

# %%
d = {'col1': [0, 1, 2, 3], 'col2': pd.Series([3,8])}
pd.DataFrame(d, index=[0, 1, 2, 3])
# Out:
#    col1  col2
# 0     0   3.0
# 1     1   8.0
# 2     2   NaN
# 3     3   NaN

# %%
df4.columns
# Out:
# RangeIndex(start=0, stop=1, step=1)

# %%
data1 = pd.read_csv("TSNE_data.csv")
data1
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M        17.99         10.38          122.80     1001.0
# 1           M        20.57         17.77          132.90     1326.0
# 2           M        19.69         21.25          130.00     1203.0
# 3           M        11.42         20.38           77.58      386.1
# 4           M        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 564         M        21.56         22.39          142.00     1479.0
# 565         M        20.13         28.25          131.20     1261.0
# 566         M        16.60         28.08          108.30      858.1
# 567         M        20.60         29.33          140.10     1265.0
# 568         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
data1.head(10)
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
# 5         M        12.45         15.70           82.57      477.1
# 6         M        18.25         19.98          119.60     1040.0
# 7         M        13.71         20.83           90.20      577.9
# 8         M        13.00         21.82           87.50      519.8
# 9         M        12.46         24.04           83.97      475.9
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760         0.30010              0.14710
# 1          0.08474           0.07864         0.08690              0.07017
# ...

# %%
data1.tail(10)
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 559         B        11.51         23.93           74.52      403.5
# 560         B        14.05         27.15           91.38      600.4
# 561         B        11.20         29.37           70.67      386.0
# 562         M        15.22         30.62          103.40      716.9
# 563         M        20.92         25.09          143.00     1347.0
# 564         M        21.56         22.39          142.00     1479.0
# 565         M        20.13         28.25          131.20     1261.0
# 566         M        16.60         28.08          108.30      858.1
# 567         M        20.60         29.33          140.10     1265.0
# 568         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 559          0.09261           0.10210         0.11120              0.04105
# ...

# %%
data1.iloc[100:125]
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 100         M       13.610         24.98           88.05      582.7
# 101         B        6.981         13.43           43.79      143.5
# 102         B       12.180         20.52           77.22      458.7
# 103         B        9.876         19.40           63.95      298.3
# 104         B       10.490         19.29           67.41      336.1
# 105         M       13.110         15.56           87.21      530.2
# 106         B       11.640         18.33           75.17      412.5
# 107         B       12.360         18.54           79.01      466.7
# 108         M       22.270         19.67          152.80     1509.0
# 109         B       11.340         21.26           72.48      396.5
# 110         B        9.777         16.99           62.50      290.2
# 111         B       12.630         20.76           82.15      480.4
# 112         B       14.260         19.65           97.83      629.9
# ...

# %%
data1.iloc[10:20,3:8]
# Out:
#     perimeter_mean  area_mean  smoothness_mean  compactness_mean  \
# 10          102.70      797.8          0.08206           0.06669
# 11          103.60      781.0          0.09710           0.12920
# 12          132.40     1123.0          0.09740           0.24580
# 13          103.70      782.7          0.08401           0.10020
# 14           93.60      578.3          0.11310           0.22930
# 15           96.73      658.8          0.11390           0.15950
# 16           94.74      684.5          0.09867           0.07200
# 17          108.10      798.8          0.11700           0.20220
# 18          130.00     1260.0          0.09831           0.10270
# 19           87.46      566.3          0.09779           0.08129
#
#     concavity_mean
# 10         0.03299
# 11         0.09954
# 12         0.20650
# 13         0.09938
# 14         0.21280
# 15         0.16390
# 16         0.07395
# 17         0.17220
# 18         0.14790
# 19         0.06664

# %%
data1[10:20]
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 10         M        16.02         23.24          102.70      797.8
# 11         M        15.78         17.89          103.60      781.0
# 12         M        19.17         24.80          132.40     1123.0
# 13         M        15.85         23.95          103.70      782.7
# 14         M        13.73         22.61           93.60      578.3
# 15         M        14.54         27.54           96.73      658.8
# 16         M        14.68         20.13           94.74      684.5
# 17         M        16.13         20.68          108.10      798.8
# 18         M        19.81         22.15          130.00     1260.0
# 19         B        13.54         14.36           87.46      566.3
#
#     smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 10          0.08206           0.06669         0.03299              0.03323
# 11          0.09710           0.12920         0.09954              0.06606
# ...

# %%
data1.iloc[[11,3,4],[5,6,8]]
# Out:
#    smoothness_mean  compactness_mean  concave points_mean
# 1          0.08474           0.07864              0.07017
# 3          0.14250           0.28390              0.10520
# 4          0.10030           0.13280              0.10430

# %%
data1.iloc[5,3]
# Out:
# 82.57

# %%
data1.iloc[[0,3],[0,3]]
# Out:
#   diagnosis  perimeter_mean
# 0         M          122.80
# 3         M           77.58

# %%
data1.loc[2]
# Out:
# diagnosis                         M
# radius_mean                   19.69
# texture_mean                  21.25
# perimeter_mean                130.0
# area_mean                    1203.0
# smoothness_mean              0.1096
# compactness_mean             0.1599
# concavity_mean               0.1974
# concave points_mean          0.1279
# symmetry_mean                0.2069
# fractal_dimension_mean      0.05999
# radius_se                    0.7456
# texture_se                   0.7869
# perimeter_se                  4.585
# area_se                       94.03
# smoothness_se               0.00615
# compactness_se              0.04006
# concavity_se                0.03832
# concave points_se           0.02058
# symmetry_se                  0.0225
# fractal_dimension_se       0.004571
# radius_worst                  23.57
# texture_worst                 25.53
# perimeter_worst               152.5
# area_worst                   1709.0
# smoothness_worst             0.1444
# ...

# %%
data1.iloc[:,[5,9]]
# Out:
#      smoothness_mean  symmetry_mean
# 0            0.11840         0.2419
# 1            0.08474         0.1812
# 2            0.10960         0.2069
# 3            0.14250         0.2597
# 4            0.10030         0.1809
# ..               ...            ...
# 564          0.11100         0.1726
# 565          0.09780         0.1752
# 566          0.08455         0.1590
# 567          0.11780         0.2397
# 568          0.05263         0.1587
#
# [569 rows x 2 columns]

# %%
data1.loc[4:50,["perimeter_worst","smoothness_se"]]
# Out:
#     perimeter_worst  smoothness_se
# 4            152.20       0.011490
# 5            103.40       0.007510
# 6            153.20       0.004314
# 7            110.60       0.008805
# 8            106.20       0.005731
# 9             97.65       0.007149
# 10           123.80       0.004029
# 11           136.50       0.005771
# 12           151.70       0.003139
# 13           112.00       0.009769
# 14           108.80       0.006429
# 15           124.10       0.005607
# 16           123.40       0.005718
# 17           136.80       0.007026
# 18           186.80       0.006494
# 19            99.70       0.008462
# 20            96.09       0.004097
# 21            65.13       0.009606
# 22           125.10       0.006789
# 23           188.00       0.004728
# 24           177.00       0.006048
# 25           152.40       0.008029
# 26           122.40       0.004452
# 27           139.90       0.010750
# 28           149.30       0.005233
# 29           134.90       0.005627
# ...

# %%
data1.loc[:,["perimeter_worst","smoothness_se"]]
# Out:
#      perimeter_worst  smoothness_se
# 0             184.60       0.006399
# 1             158.80       0.005225
# 2             152.50       0.006150
# 3              98.87       0.009110
# 4             152.20       0.011490
# ..               ...            ...
# 564           166.10       0.010300
# 565           155.00       0.005769
# 566           126.70       0.005903
# 567           184.60       0.006522
# 568            59.16       0.007189
#
# [569 rows x 2 columns]
